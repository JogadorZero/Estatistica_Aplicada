# %% [markdown]
# <a href="https://colab.research.google.com/github/JogadorZero/Estatistica_Aplicada/blob/main/Amostragem_Estratificada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import numpy as np

dataset = pd.read_csv('census.csv')

# %% [markdown]
# #Amostragem Estratificada

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
dataset['income'].value_counts()
# Out:
# income
#  <=50K    24720
#  >50K      7841
# Name: count, dtype: int64

# %% [markdown]
# #####Calculando a representatividade (%) dessas informações

# %%
7841 / len(dataset), 24720 / len(dataset)
# Out:
# (0.2408095574460244, 0.7591904425539756)

# %%
split = StratifiedShuffleSplit(test_size=0.1)
for x, y in split.split(dataset, dataset['income']):
  df_x = dataset.iloc[x]
  df_y = dataset.iloc[y]

# %%
df_x.shape, df_y.shape
# Out:
# ((29304, 15), (3257, 15))

# %%
df_y.head()
# Out:
#        age workclass  final-weight      education  education-num  \
# 20118   44   Private        304530   Some-college             10
# 3872    38   Private        170020        HS-grad              9
# 12566   44   Private        156413   Some-college             10
# 457     38   Private        351299   Some-college             10
# 17281   32   Private        372692        HS-grad              9
#
#             marital-status          occupation    relationship    race    sex  \
# 20118             Divorced        Craft-repair   Not-in-family   White   Male
# 3872    Married-civ-spouse   Machine-op-inspct         Husband   White   Male
# 12566   Married-civ-spouse        Tech-support         Husband   White   Male
# 457     Married-civ-spouse    Transport-moving         Husband   Black   Male
# 17281   Married-civ-spouse        Craft-repair         Husband   White   Male
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# 20118             0             0             55   United-States   <=50K
# 3872           3137             0             45   United-States   <=50K
# 12566             0             0             44   United-States    >50K
# 457               0             0             50   United-States   <=50K
# 17281             0             0             40   United-States   <=50K

# %%
100/len(dataset)
# Out:
# 0.0030711587481956942

# %%
split = StratifiedShuffleSplit(test_size=0.0030711587481956942)
for x, y in split.split(dataset, dataset['income']):
  df_x = dataset.iloc[x]
  df_y = dataset.iloc[y]

# %%
df_x.shape, df_y.shape
# Out:
# ((32461, 15), (100, 15))

# %%
df_y.head()
# Out:
#        age          workclass  final-weight      education  education-num  \
# 167     46          State-gov        102628        Masters             14
# 9611    19            Private        232368   Some-college             10
# 14065   38            Private        177121   Some-college             10
# 16998   39   Self-emp-not-inc        164593      Doctorate             16
# 4940    38            Private        207202        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 167                Widowed     Protective-serv       Unmarried   White
# 9611         Never-married       Other-service       Own-child   White
# 14065            Separated       Other-service   Not-in-family   White
# 16998        Never-married      Prof-specialty   Not-in-family   White
# 4940    Married-civ-spouse   Machine-op-inspct         Husband   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 167       Male             0             0             40   United-States
# 9611    Female             0             0             35   United-States
# 14065   Female             0             0             58   United-States
# 16998     Male          4787             0             40   United-States
# 4940      Male             0             0             48   United-States
#
#        income
# 167     <=50K
# 9611    <=50K
# 14065   <=50K
# 16998    >50K
# 4940     >50K

# %%
df_y['income'].value_counts()
# Out:
# income
#  <=50K    76
#  >50K     24
# Name: count, dtype: int64

# %%
def amostragem_estratificada(dataset, percentual):
  split = StratifiedShuffleSplit(test_size=percentual, random_state=1)
  for _, y in split.split(dataset, dataset['income']):
    df_y = dataset.iloc[y]
  return df_y

# %%
df_amostra_estratificada = amostragem_estratificada(dataset, 0.0030711587481956942)
df_amostra_estratificada.shape
# Out:
# (100, 15)
