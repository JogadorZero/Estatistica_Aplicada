# %% [markdown]
# <a href="https://colab.research.google.com/github/JogadorZero/Estatistica_Aplicada/blob/main/Pratica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# #Criando uma matriz NumPy

# %%
matriz = np.array([[1,2,3],[4,5,6]])

# %%
resultado = matriz * 100

# %%
print(matriz)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(resultado)
# Out:
# [[100 200 300]
#  [400 500 600]]

# %% [markdown]
# #EXEMPLO 1

# %%
Obj = Series([4, 7, -5, 3])

# %%
print(Obj)
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
type(Obj)
# Out:
# pandas.core.series.Series

# %%
Obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
Obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# #Criando uma série e especificando os índices

# %%
Obj2 = Series([4, 7, -5, 3], index=['a', 'b', 'c', 'd'])

# %%
Obj2
# Out:
# a    4
# b    7
# c   -5
# d    3
# dtype: int64

# %%
Obj2.values
# Out:
# array([ 4,  7, -5,  3])

# %%
Obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %% [markdown]
# #Exemplo 3

# %%
Obj2[Obj2 > 3]
# Out:
# a    4
# b    7
# dtype: int64

# %%
Obj2['b']
# Out:
# 7

# %%
'd' in Obj2
# Out:
# True

# %% [markdown]
# #Criando uma série a partir de um dicionário em Python

# %%
dict = {'Futebol':5200, 'Tenis':120, 'Natação':698, 'Volleyball':1550}

# %%
Obj3 = Series(dict)

# %%
Obj3
# Out:
# Futebol       5200
# Tenis          120
# Natação        698
# Volleyball    1550
# dtype: int64

# %% [markdown]
# #Criando uma lista

# %%
esportes = ['Futebol', 'Tenis', 'Natação', 'Basketball']

# %% [markdown]
# #Criando uma série e usando uma lista como índice

# %%
Obj4 = Series(dict, index=esportes)

# %%
Obj4
# Out:
# Futebol       5200.0
# Tenis          120.0
# Natação        698.0
# Basketball       NaN
# dtype: float64

# %% [markdown]
# #Comando para verificar se há valores nulos dentro da série

# %%
pd.isnull(Obj4)
# Out:
# Futebol       False
# Tenis         False
# Natação       False
# Basketball     True
# dtype: bool

# %% [markdown]
# #Comando para verificar se Não há valores nulos dentro da série

# %%
pd.notnull(Obj4)
# Out:
# Futebol        True
# Tenis          True
# Natação        True
# Basketball    False
# dtype: bool

# %% [markdown]
# #Concatenando duas séries

# %%
Obj3 + Obj4
# Out:
# Basketball        NaN
# Futebol       10400.0
# Natação        1396.0
# Tenis           240.0
# Volleyball        NaN
# dtype: float64

# %% [markdown]
# #Dando nome ao objeto

# %%
Obj4.name = 'População'

# %% [markdown]
# #Dando nome ao índice

# %%
Obj4.index.name = 'Esporte'

# %%
Obj4
# Out:
# Esporte
# Futebol       5200.0
# Tenis          120.0
# Natação        698.0
# Basketball       NaN
# Name: População, dtype: float64

# %% [markdown]
# #Data Frame

# %%
data = {'Estado': ['Santa Catarina', 'Parana', 'Goias', 'Bahia', 'Minas Gerais'],
'Ano': [2002, 2003, 2004, 2005, 2006],
'População': [1.5, 1.7, 3.6, 2.4, 2.9]}

# %%
frame = DataFrame(data)

# %%
frame
# Out:
#            Estado   Ano  População
# 0  Santa Catarina  2002        1.5
# 1          Parana  2003        1.7
# 2           Goias  2004        3.6
# 3           Bahia  2005        2.4
# 4    Minas Gerais  2006        2.9

# %%
type(frame)
# Out:
# pandas.core.frame.DataFrame

# %%
DataFrame(data, columns=['Ano', 'Estado', 'População'])
# Out:
#     Ano          Estado  População
# 0  2002  Santa Catarina        1.5
# 1  2003          Parana        1.7
# 2  2004           Goias        3.6
# 3  2005           Bahia        2.4
# 4  2006    Minas Gerais        2.9

# %%
frame2 = DataFrame(data, columns=['Ano', 'Estado', 'População', 'Débito'],
index=['um', 'dois', 'tres', 'quatro', 'cinco'])

# %% [markdown]
# #Imprimindo o DataFrame

# %%
frame2
# Out:
#          Ano          Estado  População Débito
# um      2002  Santa Catarina        1.5    NaN
# dois    2003          Parana        1.7    NaN
# tres    2004           Goias        3.6    NaN
# quatro  2005           Bahia        2.4    NaN
# cinco   2006    Minas Gerais        2.9    NaN

# %% [markdown]
# #Imprimindo apenas uma coluna do DataFrame

# %%
frame2['Estado']
# Out:
# um        Santa Catarina
# dois              Parana
# tres               Goias
# quatro             Bahia
# cinco       Minas Gerais
# Name: Estado, dtype: object

# %% [markdown]
# #Usando o NumPy para alimentar uma das colunas do DataFrame

# %%
frame2['Débito'] = np.arange(5.)

# %%
frame2
# Out:
#          Ano          Estado  População  Débito
# um      2002  Santa Catarina        1.5     0.0
# dois    2003          Parana        1.7     1.0
# tres    2004           Goias        3.6     2.0
# quatro  2005           Bahia        2.4     3.0
# cinco   2006    Minas Gerais        2.9     4.0

# %%
frame2.values
# Out:
# array([[2002, 'Santa Catarina', 1.5, 0.0],
#        [2003, 'Parana', 1.7, 1.0],
#        [2004, 'Goias', 3.6, 2.0],
#        [2005, 'Bahia', 2.4, 3.0],
#        [2006, 'Minas Gerais', 2.9, 4.0]], dtype=object)

# %% [markdown]
# #Resumo do DataFrame com todas as informações contidas

# %%
frame2.describe()
# Out:
#                Ano  População    Débito
# count     5.000000   5.000000  5.000000
# mean   2004.000000   2.420000  2.000000
# std       1.581139   0.864292  1.581139
# min    2002.000000   1.500000  0.000000
# 25%    2003.000000   1.700000  1.000000
# 50%    2004.000000   2.400000  2.000000
# 75%    2005.000000   2.900000  3.000000
# max    2006.000000   3.600000  4.000000

# %% [markdown]
# #Tipos de dados no DataFrame

# %%
frame2.dtypes
# Out:
# Ano            int64
# Estado        object
# População    float64
# Débito       float64
# dtype: object

# %%
frame2.index
# Out:
# Index(['um', 'dois', 'tres', 'quatro', 'cinco'], dtype='object')

# %%
frame2.columns
# Out:
# Index(['Ano', 'Estado', 'População', 'Débito'], dtype='object')

# %%
frame2.values
# Out:
# array([[2002, 'Santa Catarina', 1.5, 0.0],
#        [2003, 'Parana', 1.7, 1.0],
#        [2004, 'Goias', 3.6, 2.0],
#        [2005, 'Bahia', 2.4, 3.0],
#        [2006, 'Minas Gerais', 2.9, 4.0]], dtype=object)

# %%
frame2['Ano']
# Out:
# um        2002
# dois      2003
# tres      2004
# quatro    2005
# cinco     2006
# Name: Ano, dtype: int64

# %%
frame2.Ano
# Out:
# um        2002
# dois      2003
# tres      2004
# quatro    2005
# cinco     2006
# Name: Ano, dtype: int64

# %%
frame2[:2]
# Out:
#        Ano          Estado  População  Débito
# um    2002  Santa Catarina        1.5     0.0
# dois  2003          Parana        1.7     1.0

# %%
frame2[:3]
# Out:
#        Ano          Estado  População  Débito
# um    2002  Santa Catarina        1.5     0.0
# dois  2003          Parana        1.7     1.0
# tres  2004           Goias        3.6     2.0

# %% [markdown]
# #Criando um dicionário

# %%
web_stats = {'Dias':[1,2,3,4,5,6,7],
'Visitantes':[45,23,67,78,23,12,14],
'Taxas':[11,22,33,44,55,66,77]}

# %%
df = DataFrame(web_stats)

# %%
df
# Out:
#    Dias  Visitantes  Taxas
# 0     1          45     11
# 1     2          23     22
# 2     3          67     33
# 3     4          78     44
# 4     5          23     55
# 5     6          12     66
# 6     7          14     77

# %% [markdown]
# #Visualizando uma coluna index

# %%
df.set_index('Dias')
# Out:
#       Visitantes  Taxas
# Dias
# 1             45     11
# 2             23     22
# 3             67     33
# 4             78     44
# 5             23     55
# 6             12     66
# 7             14     77

# %%
df.head()
# Out:
#    Dias  Visitantes  Taxas
# 0     1          45     11
# 1     2          23     22
# 2     3          67     33
# 3     4          78     44
# 4     5          23     55

# %%
df['Visitantes']
# Out:
# 0    45
# 1    23
# 2    67
# 3    78
# 4    23
# 5    12
# 6    14
# Name: Visitantes, dtype: int64

# %%
df[['Visitantes', 'Taxas']]
# Out:
#    Visitantes  Taxas
# 0          45     11
# 1          23     22
# 2          67     33
# 3          78     44
# 4          23     55
# 5          12     66
# 6          14     77
